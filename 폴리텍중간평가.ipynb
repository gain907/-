# %% [markdown]
# #[중간평가]

# %% [markdown]
# ### KNN 모델을 이용해서 IRIS 데이터 학습
# - IRIS 데이터 구성
#  - 특징(문제): sepal_length,sepal_width, petal_length petal_width
#  - 특징(답지): species

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### [문제1] pandas, numpy 가져오기
#  - pandas
#  - numpy

# %%
#[정답]

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ###[문제2]데이터 가져오기

# %%
iris_data =

# %% [markdown]
# ###[문제3] 데이터 정보 가져오기

# %% [markdown]
# ###[문제4] 데이터 통계값 가져오기

# %% [markdown]
# ###[문제5] ris_data 의 개수는 몇개인가요?

# %% [markdown]
# ### [문제6] train, test 데이터를 8:2 비율로 나눠주세요

# %% [markdown]
# ###[문제7]
#  - irs_df 데이터의 크기 확인
#  - train 데이터의 크기 확인
#  - test 데이터의 크기 확인

# %% [markdown]
# ### [문제8] train,test 데이터 문제,답지 나누기
# - X_train(문제)
# - y_train(답지)
# - X_test(문제)
# - y_test(답지)

# %% [markdown]
# ### [문제9] train,test 데이터 문제,답지 크기 확인

# %% [markdown]
# ### 모델 생성

# %%
# 머신러닝 모델 만들기  KNN 모델 불러오기
from sklearn.neighbors import KNeighborsClassifier
# 모델 생성해서 새로운 변수에 넣어주세요
knn_model = KNeighborsClassifier(n_neighbors=1)

# %% [markdown]
# ###[문제10] 모델 학습
#  - train 데이터의 문제 답지를 가지고 학습시켜주세요

# %% [markdown]
# ###[문제11] 모델 예측
# - test데이터를 가지고 예측해 주세요

# %% [markdown]
# ###[문제12] 모델을 평가해 주세요

# %%
# 모델 평가
from sklearn.metrics import accuracy_score
