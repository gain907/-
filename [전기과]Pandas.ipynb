# %% [markdown]
# ### [기초통계학] 판다스 실습
# - 진로희망 도수 프레임 제작

# %%
# 딕셔너리 {key:value,key:value,....}
# {'a':'나는 정말 잘생긴','b':'훌륭한 사람입니다'}
ai = {'진로희망' : ['빅데이터 전문가','자영업','웹개발자','대학원','합계'], '도수':[6,7,3,4,20]}


ai
# Out:
# {'진로희망': ['빅데이터 전문가', '자영업', '웹개발자', '대학원', '합계'], '도수': [6, 7, 3, 4, 20]}

# %%
# pandas DataFrame 제작
import pandas as pd
ai_df = pd.DataFrame(ai)
ai_df
# Out:
#        진로희망  도수
# 0  빅데이터 전문가   6
# 1       자영업   7
# 2      웹개발자   3
# 3       대학원   4
# 4        합계  20

# %%
print(type(ai), type(ai_df))
# Out:
# <class 'dict'> <class 'pandas.core.frame.DataFrame'>

# %%
# /content/drive/MyDrive/폴리텍전남캠퍼스/data/titanic.csv
dir = '/content/drive/MyDrive/폴리텍전남캠퍼스/data/titanic.csv'

# %%
import pandas as pd
# csv파일 열기 pd.read_csv('경로')
# 방법1
#pd.read_csv('/content/drive/MyDrive/폴리텍전남캠퍼스/data/titanic.csv')
# 방법2
titanic_df = pd.read_csv(dir)

titanic_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# 최근데이터 5개만 보여주세요
titanic_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# 데이터 크기 shape
type(titanic_df)
# Out:
# pandas.core.frame.DataFrame

# %%
# 데이터 정보 확인
titanic_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
# 데이터의 평균
# describe()
titanic_df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200
